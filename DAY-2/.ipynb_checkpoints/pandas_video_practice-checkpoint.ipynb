# %% [markdown]
# # Pandas Practices

# %%
# Import pandas and numpy
import numpy as np
import pandas as pd

# %%
# Create Series
series = pd.Series([3, 53, 22, 52, 43])
print(series)
# Out:
# 0     3
# 1    53
# 2    22
# 3    52
# 4    43
# dtype: int64

# %%
# Check the values of the series
series.values
# Out:
# array([ 3, 53, 22, 52, 43])

# %%
# Check datatype of the series
series.dtype
# Out:
# dtype('int64')

# %%
# Check the indexing of the series
series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Check the heading of series
series.name

# %%
# Assign the heading of series
series.name = "Numbers"
print(series)
# Out:
# 0     3
# 1    53
# 2    22
# 3    52
# 4    43
# Name: Numbers, dtype: int64

# %%
# Indexing 
series[0] # Get the first element
series[len(series) - 1] # Get the last element
series[0:3] # Get the range of the element
# Out:
# 0     3
# 1    53
# 2    22
# Name: Numbers, dtype: int64

# %%
# Indexing with iloc function
series.iloc[3] # Get specific element
series.iloc[[1, 2, 4]] # Get specifi range of element
# Out:
# 1    53
# 2    22
# 4    43
# Name: Numbers, dtype: int64

# %%
# Assign the name to the index of series
index = ["Apple", "Banana", "Mango", "Orange", "Grape"]
series.index = index
series.name = "Calories"
series
# Out:
# Apple      3
# Banana    53
# Mango     22
# Orange    52
# Grape     43
# Name: Calories, dtype: int64

# %%
# Access the series with name index
series["Mango"]
# Out:
# np.int64(22)

# %%
# Accessing label based indexing with loc funtion
series.loc["Mango"] # Get specific element
series.loc[["Mango", "Grape", "Banana"]] # Get specific range of element
# Out:
# Mango     22
# Grape     43
# Banana    53
# Name: Calories, dtype: int64

# %%
# Create Series with the help of dictionary
protien = {
    "Beef": 39,
    "Chicken": 26,
    "Egg": 6,
    "Rice": 1
}

series2 = pd.Series(protien, name="Protien per 100gm")
series2
# Out:
# Beef       39
# Chicken    26
# Egg         6
# Rice        1
# Name: Protien per 100gm, dtype: int64

# %%
# Conditional Selection
series2[series2 > 6]
# Out:
# Beef       39
# Chicken    26
# Name: Protien per 100gm, dtype: int64

# %%
# Logical and, or, and not operation
series2[(series2 > 6) & (series2 < 39)]
series2[(series2 > 6) | (series2 < 20)]
# Out:
# Beef       39
# Chicken    26
# Egg         6
# Rice        1
# Name: Protien per 100gm, dtype: int64

# %%
# Modify the element of series
series2["Beef"] = 40
series2
# Out:
# Beef       40
# Chicken    26
# Egg         6
# Rice        1
# Name: Protien per 100gm, dtype: int64

# %%
# exercise
ser = pd.Series(['a', np.nan, 1, np.nan, 2])
ser.notnull().sum()
# Out:
# np.int64(3)

# %%
# Create pandas dataframe
data = {
    "Name": ["Syful", "Taifur", "Rohan", "Arman", "Sufian", "Arifa", "Taifur"],
    "Age": [25, 24, 25, np.nan, 27, 21, 24],
    "Department": ["IT", "Marketing", "HR", "IT", "HR", "HR", "Marketing"],
    "Salary": [60000, 45000, 40000, 65000, np.nan, 50000, 45000]
}
df = pd.DataFrame(data)
df
# Out:
#      Name   Age Department   Salary
# 0   Syful  25.0         IT  60000.0
# 1  Taifur  24.0  Marketing  45000.0
# 2   Rohan  25.0         HR  40000.0
# 3   Arman   NaN         IT  65000.0
# 4  Sufian  27.0         HR      NaN
# 5   Arifa  21.0         HR  50000.0
# 6  Taifur  24.0  Marketing  45000.0

# %%
# Access the first three rows of data
df.head(3)
# Out:
#      Name   Age Department   Salary
# 0   Syful  25.0         IT  60000.0
# 1  Taifur  24.0  Marketing  45000.0
# 2   Rohan  25.0         HR  40000.0

# %%
# Access the last three rows of data
df.tail(3)
# Out:
#      Name   Age Department   Salary
# 4  Sufian  27.0         HR      NaN
# 5   Arifa  21.0         HR  50000.0
# 6  Taifur  24.0  Marketing  45000.0

# %%
# Access data with iloc
df.iloc[1:3, [0, 2]]
# Out:
#      Name Department
# 1  Taifur  Marketing
# 2   Rohan         HR

# %%
# Access data with loc
df.loc[2:, ["Name", "Salary"]]
# Out:
#      Name   Salary
# 2   Rohan  40000.0
# 3   Arman  65000.0
# 4  Sufian      NaN
# 5   Arifa  50000.0
# 6  Taifur  45000.0

# %%
# Get column
df["Name"] # Get single column
df[["Name", "Salary"]] # Get range of columns
# Out:
#      Name   Salary
# 0   Syful  60000.0
# 1  Taifur  45000.0
# 2   Rohan  40000.0
# 3   Arman  65000.0
# 4  Sufian      NaN
# 5   Arifa  50000.0
# 6  Taifur  45000.0

# %%
# Drop column if the column has nan value
df.drop("Age", axis=1)
# Out:
#      Name Department   Salary
# 0   Syful         IT  60000.0
# 1  Taifur  Marketing  45000.0
# 2   Rohan         HR  40000.0
# 3   Arman         IT  65000.0
# 4  Sufian         HR      NaN
# 5   Arifa         HR  50000.0
# 6  Taifur  Marketing  45000.0

# %%
df
# Out:
#      Name   Age Department   Salary
# 0   Syful  25.0         IT  60000.0
# 1  Taifur  24.0  Marketing  45000.0
# 2   Rohan  25.0         HR  40000.0
# 3   Arman   NaN         IT  65000.0
# 4  Sufian  27.0         HR      NaN
# 5   Arifa  21.0         HR  50000.0
# 6  Taifur  24.0  Marketing  45000.0

# %%
# Get the shape of dataset or dataframe
df.shape
# Out:
# (7, 4)

# %%
# Get basic info about each column of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        7 non-null      object
#  1   Age         6 non-null      float64
#  2   Department  7 non-null      object
#  3   Salary      6 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 356.0+ bytes

# %%
# Get the basic statistics of dataframe
df.describe()
# Out:
#              Age        Salary
# count   6.000000      6.000000
# mean   24.333333  50833.333333
# std     1.966384   9703.951085
# min    21.000000  40000.000000
# 25%    24.000000  45000.000000
# 50%    24.500000  47500.000000
# 75%    25.000000  57500.000000
# max    27.000000  65000.000000

# %%
# Broadcasting employ salary by 5000
df["Salary"] = df["Salary"] + 5000
df
# Out:
#      Name   Age Department   Salary
# 0   Syful  25.0         IT  65000.0
# 1  Taifur  24.0  Marketing  50000.0
# 2   Rohan  25.0         HR  45000.0
# 3   Arman   NaN         IT  70000.0
# 4  Sufian  27.0         HR      NaN
# 5   Arifa  21.0         HR  55000.0
# 6  Taifur  24.0  Marketing  50000.0

# %%
# Raname column name 
df.rename(columns = {"Department": "Dept."}, inplace=True)
df
# Out:
#      Name   Age      Dept.   Salary
# 0   Syful  25.0         IT  65000.0
# 1  Taifur  24.0  Marketing  50000.0
# 2   Rohan  25.0         HR  45000.0
# 3   Arman   NaN         IT  70000.0
# 4  Sufian  27.0         HR      NaN
# 5   Arifa  21.0         HR  55000.0
# 6  Taifur  24.0  Marketing  50000.0

# %%
# Get the unique values in particular column
df["Dept."].unique()
# Out:
# array(['IT', 'Marketing', 'HR'], dtype=object)

# %%
# Group by the columns unique values to get the count of the particular values
df["Dept."].value_counts()
# Out:
# Dept.
# HR           3
# IT           2
# Marketing    2
# Name: count, dtype: int64

# %%
df["Promoted Salary"] = df["Salary"] + df["Salary"] * 0.1
df
# Out:
#      Name   Age      Dept.   Salary  Promoted Salary
# 0   Syful  25.0         IT  65000.0          71500.0
# 1  Taifur  24.0  Marketing  50000.0          55000.0
# 2   Rohan  25.0         HR  45000.0          49500.0
# 3   Arman   NaN         IT  70000.0          77000.0
# 4  Sufian  27.0         HR      NaN              NaN
# 5   Arifa  21.0         HR  55000.0          60500.0
# 6  Taifur  24.0  Marketing  50000.0          55000.0

# %%
# Check the null value per column
df.isnull().sum()
# Out:
# Name               0
# Age                1
# Dept.              0
# Salary             1
# Promoted Salary    1
# dtype: int64

# %%
# Drop null value
df.dropna() # Drop a row if any data is null in the particular row
df.dropna(how="all") # Drop a row if all data is null in the particular row
df.dropna(how="any") # It works like the default
# Out:
#      Name   Age      Dept.   Salary  Promoted Salary
# 0   Syful  25.0         IT  65000.0          71500.0
# 1  Taifur  24.0  Marketing  50000.0          55000.0
# 2   Rohan  25.0         HR  45000.0          49500.0
# 5   Arifa  21.0         HR  55000.0          60500.0
# 6  Taifur  24.0  Marketing  50000.0          55000.0

# %%
# Fill the null value
df.fillna(0) # Fill the null value with zero
df["Age"].fillna(df["Age"].mean()) # Fill the null value of age column with average
df["Salary"].fillna(df["Salary"].median()) # Fill the null value of salary with median
# df["Age"].fillna(method="ffill") # Fill the null value with forward fill
df["Age"].ffill() # same as above
df["Age"].fillna(method="bfill") # Fill the null value with backword fill
# Out:
# C:\Users\syful\AppData\Local\Temp\ipykernel_9008\1383276684.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["Age"].fillna(method="bfill") # Fill the null value with backword fill
# 0    25.0
# 1    24.0
# 2    25.0
# 3    27.0
# 4    27.0
# 5    21.0
# 6    24.0
# Name: Age, dtype: float64

# %%
# Change any particular value corresponding to row and column
df["Name"] = df["Name"].replace("Rohan", "Nazmul")
df
# Out:
#      Name   Age      Dept.   Salary  Promoted Salary
# 0   Syful  25.0         IT  65000.0          71500.0
# 1  Taifur  24.0  Marketing  50000.0          55000.0
# 2  Nazmul  25.0         HR  45000.0          49500.0
# 3   Arman   NaN         IT  70000.0          77000.0
# 4  Sufian  27.0         HR      NaN              NaN
# 5   Arifa  21.0         HR  55000.0          60500.0
# 6  Taifur  24.0  Marketing  50000.0          55000.0

# %%
# Get the duplicated dataset
duplicated = df[df.duplicated(keep="first")]
duplicated
# Out:
#      Name   Age      Dept.   Salary  Promoted Salary
# 6  Taifur  24.0  Marketing  50000.0          55000.0

# %%
# drop the duplicated row
df = df.drop_duplicates()
df
# Out:
#      Name   Age      Dept.   Salary  Promoted Salary
# 0   Syful  25.0         IT  65000.0          71500.0
# 1  Taifur  24.0  Marketing  50000.0          55000.0
# 2  Nazmul  25.0         HR  45000.0          49500.0
# 3   Arman   NaN         IT  70000.0          77000.0
# 4  Sufian  27.0         HR      NaN              NaN
# 5   Arifa  21.0         HR  55000.0          60500.0

# %%
# Invalid values with lambda function
df["Promoted Salary"] = df["Promoted Salary"].apply(lambda x: x/1.1 if x > 70000 else x)
# Out:
# C:\Users\syful\AppData\Local\Temp\ipykernel_9008\521675289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Promoted Salary"] = df["Promoted Salary"].apply(lambda x: x/1.1 if x > 70000 else x)

# %%
df
# Out:
#      Name   Age      Dept.   Salary  Promoted Salary
# 0   Syful  25.0         IT  65000.0          65000.0
# 1  Taifur  24.0  Marketing  50000.0          55000.0
# 2  Nazmul  25.0         HR  45000.0          49500.0
# 3   Arman   NaN         IT  70000.0          70000.0
# 4  Sufian  27.0         HR      NaN              NaN
# 5   Arifa  21.0         HR  55000.0          60500.0

# %%
# apply and lambda function
def double_age(x):
    return x * x

df["Age"] = df["Age"].apply(double_age)
df
# Out:
# C:\Users\syful\AppData\Local\Temp\ipykernel_9008\801109615.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].apply(double_age)
#      Name    Age      Dept.   Salary  Promoted Salary
# 0   Syful  625.0         IT  65000.0          65000.0
# 1  Taifur  576.0  Marketing  50000.0          55000.0
# 2  Nazmul  625.0         HR  45000.0          49500.0
# 3   Arman    NaN         IT  70000.0          70000.0
# 4  Sufian  729.0         HR      NaN              NaN
# 5   Arifa  441.0         HR  55000.0          60500.0

# %%
df["Age"] = df["Age"].apply(lambda x: np.sqrt(x))
df
# Out:
# C:\Users\syful\AppData\Local\Temp\ipykernel_9008\3363046449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].apply(lambda x: np.sqrt(x))
#      Name   Age      Dept.   Salary  Promoted Salary
# 0   Syful  25.0         IT  65000.0          65000.0
# 1  Taifur  24.0  Marketing  50000.0          55000.0
# 2  Nazmul  25.0         HR  45000.0          49500.0
# 3   Arman   NaN         IT  70000.0          70000.0
# 4  Sufian  27.0         HR      NaN              NaN
# 5   Arifa  21.0         HR  55000.0          60500.0

# %% [markdown]
# # Pandas Practice From Another Video

# %%
# import pandas and numpy
import pandas as pd
import numpy as np

# %%
# Create Series
values = [10, 20, 30, 40, 50, 60]
s = pd.Series(values, index=["a", "b", "c", "d", "e", "f"], name="Numbers")
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# Name: Numbers, dtype: int64

# %%
# Crete DataFrame
df = pd.DataFrame({
    "name": ["Mike", "Bob", "Alice"],
    "age": [30, 80, 45],
    "job": ["Programmer", "Clerk", "Designer"]
})

df = df.set_index("name")
df
# Out:
#        age         job
# name
# Mike    30  Programmer
# Bob     80       Clerk
# Alice   45    Designer

# %%
# Reset index
df.reset_index(inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 # Reset index
# ----> 2 df.reset_index(inplace=True)
#       3 df
#
# File D:\DATA-SCIENCE\venv\Lib\site-packages\pandas\core\series.py:1769, in Series.reset_index(self, level, drop, name, inplace, allow_duplicates)
#    1765         return self._constructor(
#    1766             self._values.copy(), index=new_index, copy=False, dtype=self.dtype
#    1767         ).__finalize__(self, method="reset_index")
#    1768 elif inplace:
# -> 1769     raise TypeError(
#    1770         "Cannot reset_index inplace on a Series to create a DataFrame"
#    1771     )
#    1772 else:
#    1773     if name is lib.no_default:
#    1774         # For backwards compatibility, keep columns as [0] instead of
#    1775         #  [None] when self.name is None
#
# TypeError: Cannot reset_index inplace on a Series to create a DataFrame

# %%
# export as csv
df.to_csv("my-data.csv", index=None)

# %%
# import data
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing(as_frame=True).frame

# %%
data.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
data.shape
# Out:
# (20640, 9)

# %%
# Get the random data
data.sample(5)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 10385  6.4114      15.0  7.527559   1.049869      2529.0  3.318898     33.60
# 13332  3.9336      15.0  5.553191   1.068740      2039.0  3.337152     34.04
# 16507  4.4213      11.0  7.345936   1.132325      1605.0  3.034026     37.74
# 15515  5.4819      12.0  5.759346   0.962617      1226.0  2.864486     33.17
# 1135   2.3711      20.0  5.397015   0.997015       763.0  2.277612     39.74
#
#        Longitude  MedHouseVal
# 10385    -117.65        2.787
# 13332    -117.65        1.510
# 16507    -121.11        1.827
# 15515    -117.10        1.838
# 1135     -121.64        1.218

# %%
# Get the columns of dataset
list(data.columns)
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude',
#  'MedHouseVal']

# %%
# Set the max columns you can see
pd.options.display.max_columns = 500
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 0        -122.23        4.526
# 1        -122.22        3.585
# 2        -122.24        3.521
# 3        -122.25        3.413
# 4        -122.25        3.422
# ...          ...          ...
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
# Get the statistics of individual column
data["HouseAge"].describe()
# Out:
# count    20640.000000
# mean        28.639486
# std         12.585558
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: HouseAge, dtype: float64

# %%
# Access value with at or iat
df.at["Mike", "age"]
# Out:
# np.int64(30)

# %%
# apply custom function
df = pd.DataFrame({
    "name": ["Mike", "Bob", "Alice"],
    "age": [30, 80, 45],
    "job": ["Programmer", "Clerk", "Designer"]
})
def double_age(x):
    return x * 2

def profession(x):
    if x.endswith("r"):
        return "Tech"
    else:
        return x

df["age"] = df["age"].apply(double_age)
df["job"] = df["job"].apply(profession)
df
# Out:
#     name  age    job
# 0   Mike   60   Tech
# 1    Bob  160  Clerk
# 2  Alice   90   Tech

# %%
# Use function with the use of lambda function
df["age"] = df["age"].apply(lambda x: x / 2 if x >= 60 else x)
df
# Out:
#     name   age    job
# 0   Mike  30.0   Tech
# 1    Bob  80.0  Clerk
# 2  Alice  45.0   Tech

# %%
# Create new column with combinging other column
df["summary"] = df.apply(lambda row: f"{row["age"]}-{row["job"]}", axis=1)
df
# Out:
#     name   age    job     summary
# 0   Mike  30.0   Tech   30.0-Tech
# 1    Bob  80.0  Clerk  80.0-Clerk
# 2  Alice  45.0   Tech   45.0-Tech

# %%
# Drop any column
df = df.drop("summary", axis=1)
df
# Out:
#     name   age    job
# 0   Mike  30.0   Tech
# 1    Bob  80.0  Clerk
# 2  Alice  45.0   Tech

# %%
# iterate through the rows
for i, row in df.iterrows():
    print(i)
    print(row)
# Out:
# 0
# name    Mike
# age     30.0
# job     Tech
# Name: 0, dtype: object
# 1
# name      Bob
# age      80.0
# job     Clerk
# Name: 1, dtype: object
# 2
# name    Alice
# age      45.0
# job      Tech
# Name: 2, dtype: object

# %%
# iterate through column
for i, col in df.items():
    print(i)
    print(col)
# Out:
# name
# 0     Mike
# 1      Bob
# 2    Alice
# Name: name, dtype: object
# age
# 0    30.0
# 1    80.0
# 2    45.0
# Name: age, dtype: float64
# job
# 0     Tech
# 1    Clerk
# 2     Tech
# Name: job, dtype: object

# %%
# Set the birthday 
import datetime as dt
df["birthday"] = df["age"].apply(lambda x: dt.datetime.now() - dt.timedelta(days=365*x))
df
# Out:
#     name   age    job                   birthday
# 0   Mike  30.0   Tech 1995-12-02 11:31:52.734919
# 1    Bob  80.0  Clerk 1945-12-14 11:31:52.734940
# 2  Alice  45.0   Tech 1980-12-05 11:31:52.734946

# %%
df[df["birthday"].dt.year > 1950]
# Out:
#     name   age   job                   birthday
# 0   Mike  30.0  Tech 1995-12-02 11:31:52.734919
# 2  Alice  45.0  Tech 1980-12-05 11:31:52.734946

# %%
df[df["age"].isin([30.0, 45.0])]
# Out:
#     name   age   job                   birthday
# 0   Mike  30.0  Tech 1995-12-02 11:31:52.734919
# 2  Alice  45.0  Tech 1980-12-05 11:31:52.734946

# %%
# You can use query function to do use condition easily
df["age"] = df["age"].astype("int64")
df.query("age < 50")
# Out:
#     name  age   job                   birthday
# 0   Mike   30  Tech 1995-12-02 11:31:52.734919
# 2  Alice   45  Tech 1980-12-05 11:31:52.734946

# %%
# Use groupby method
df.groupby("job").agg({
    "age": ["sum", "mean"],
    "birthday": "count"
})
# Out:
#       age       birthday
#       sum  mean    count
# job
# Clerk  80  80.0        1
# Tech   75  37.5        2

# %%
# Sort the dataframe
df.sort_values("age", ascending=False)
# Out:
#     name  age    job                   birthday
# 1    Bob   80  Clerk 1945-12-14 11:31:52.734940
# 2  Alice   45   Tech 1980-12-05 11:31:52.734946
# 0   Mike   30   Tech 1995-12-02 11:31:52.734919

# %%
# Concatenate the dataset
df1 = pd.DataFrame({
    "Item": ["A", "B", "C"],
    "Price": [10, 20, 30]
})

df2 = pd.DataFrame({
    "Item": ["D", "E", "F"],
    "Price": [40, 50, 60]
})

pd.concat([df1, df2]).reset_index().drop("index", axis=1)
# Out:
#   Item  Price
# 0    A     10
# 1    B     20
# 2    C     30
# 3    D     40
# 4    E     50
# 5    F     60

# %%
# More Join functionalities
df1 = pd.DataFrame({
    "Item": ["A", "B", "C"],
    "Price": [10, 20, 30]
})

df2 = pd.DataFrame({
    "Country": ["X", "Y", "Z"],
    "Available": [True, True, False]
})

# Outer join
pd.concat([df1, df2])
pd.concat([df1, df2], axis=1)
# Out:
#   Item  Price Country  Available
# 0    A     10       X       True
# 1    B     20       Y       True
# 2    C     30       Z      False

# %%
df3 = pd.DataFrame({
    "Item": ["B", "C", "D"],
    "Country": ["X", "Y", "Z"]
})

# %%
# Inner join
pd.merge(df1, df3)

# Outer join
pd.merge(df1, df3, how="outer")

# Left join
pd.merge(df1, df3, how="left")

# Right join
pd.merge(df1, df3, how="right")

# Join based on item column
pd.merge(df1, df3, on="Item", how="outer")
# Out:
#   Item  Price Country
# 0    A   10.0     NaN
# 1    B   20.0       X
# 2    C   30.0       Y
# 3    D    NaN       Z

# %%
# Join based on index
df4 = pd.DataFrame({
    "Price": [10, 20, 30]
}, index=["A", "B", "C"])

df5 = pd.DataFrame({
    "Country": ["X", "Y", "Z"]
}, index=["B", "C", "D"])

df4.join(df5, how="inner")
# Out:
#    Price Country
# B     20       X
# C     30       Y
